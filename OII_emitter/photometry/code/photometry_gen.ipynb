# %%
import multibandphotometry as mbp

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import os
from glob import glob
from astropy.visualization import ZScaleInterval
from astropy.visualization import ImageNormalize
from astropy.wcs import WCS
from astropy.nddata import Cutout2D
from astropy.coordinates import SkyCoord
import astropy.units as u
import numpy as np
import matplotlib.gridspec as gridspec
from astropy.table import Table
from scipy import interpolate
import scipy.ndimage as ndimage
from photutils.aperture import SkyEllipticalAperture, SkyCircularAperture
from photutils.aperture import aperture_photometry
from astropy.visualization import simple_norm
import pandas as pd
from astropy.stats import SigmaClip
from astropy.stats import sigma_clipped_stats
from photutils.aperture import SkyEllipticalAperture, SkyCircularAperture

# %%
from pkg_resources import resource_filename, resource_listdir

# %%
resource_filename('sedpy', '/data/filters')
# Out:
# '/home/lupengjun/.local/lib/python3.10/site-packages/sedpy/data/filters'

# %%
source_position = SkyCoord(150.15949, 2.1914772, frame='icrs', unit=u.deg)
z = 0.924

# %%
#drop_telescope = ['JWST', 'HST', 'CFHT', 'gGEMINI', 'SUBARU', 'VISTA','UKIRT']
phot = mbp.MultiBandPhotometry(source_position, z, drop_telescopes=['GEMINI','UKIRT','SPITZER', 'SUBARU', 'CFHT', 'VISTA'], psf_homo='F444W')
#flux_df, error_df, area_df = phot.measure_flux(method='ellipse')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 55924.000000 from DATE-OBS'. [astropy.wcs.wcs]

# %%
flux_df, error_df, area_df = phot.measure_flux(method='downleft', bkg_regenerate=False, error_method='local')
plt.savefig('../band_cutout_downleft.png')
# Out:
# HST_F606W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# HST_F814W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# HST_F125W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# HST_F160W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:331: RuntimeWarning: divide by zero encountered in divide
#   rms_map = np.sqrt(1/rms_map) #weight map = 1/sigma***2
# JWST_F115W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:331: RuntimeWarning: divide by zero encountered in divide
#   rms_map = np.sqrt(1/rms_map) #weight map = 1/sigma***2
# JWST_F150W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:331: RuntimeWarning: divide by zero encountered in divide
#   rms_map = np.sqrt(1/rms_map) #weight map = 1/sigma***2
# JWST_F277W convolved to target psf!
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:331: RuntimeWarning: divide by zero encountered in divide
#   rms_map = np.sqrt(1/rms_map) #weight map = 1/sigma***2
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:178: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.around(new_xticks, 1).astype(str))
# /home/lupengjun/OII_emitter/photometry/code/multibandphotometry.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.around(new_yticks, 1).astype(str))

# %%
flux_df.to_csv('../output/flux_sum_space_homo_downleft.csv')
error_df.to_csv('../output/error_sum_space_homo_downleft.csv')

# %%
error_df/flux_df
# Out:
#             HST      JWST
# F606W  0.192549       NaN
# F814W  0.083638       NaN
# F125W  0.012977       NaN
# F160W  0.008575       NaN
# F115W       NaN  0.046839
# F150W       NaN  0.014821
# F277W       NaN  0.001795
# F444W       NaN  0.001158

# %%
flux_df.to_csv('../output/flux_sum_ellipse_v2.csv')
error_df.to_csv('../output/error_sum_ellipse_v2.csv')

# %% [markdown]
# microJansky to ABmagnitude

# %%
flux_df = pd.read_csv('../output/flux_sum_homo_ellipse_v1.csv', index_col=0)

# %%
flux_df
# Out:
#               HST       JWST    SUBARU       CFHT      VISTA
# F606W    0.714755        NaN       NaN        NaN        NaN
# F814W    2.290434        NaN       NaN        NaN        NaN
# F125W    6.684799        NaN       NaN        NaN        NaN
# F160W   10.182298        NaN       NaN        NaN        NaN
# F115W         NaN   5.878887       NaN        NaN        NaN
# F150W         NaN  10.248510       NaN        NaN        NaN
# F277W         NaN  36.055816       NaN        NaN        NaN
# F444W         NaN  43.086811       NaN        NaN        NaN
# HSC-G         NaN        NaN  0.290993        NaN        NaN
# HSC-I         NaN        NaN  1.718228        NaN        NaN
# HSC-R         NaN        NaN  0.652907        NaN        NaN
# HSC-Y         NaN        NaN  3.406124        NaN        NaN
# HSC-Z         NaN        NaN  2.708378        NaN        NaN
# IB0945        NaN        NaN  3.233346        NaN        NaN
# NB0387        NaN        NaN  0.093811        NaN        NaN
# NB0527        NaN        NaN  0.384661        NaN        NaN
# NB0718        NaN        NaN  2.014924        NaN        NaN
# NB0816        NaN        NaN  2.012207        NaN        NaN
# NB0921        NaN        NaN  2.773247        NaN        NaN
# NB0973        NaN        NaN  3.301394        NaN        NaN
# H             NaN        NaN       NaN  11.419270  10.260810
# i             NaN        NaN       NaN   1.623298        NaN
# Ks            NaN        NaN       NaN  22.567042  20.352906
# u             NaN        NaN       NaN   0.173342        NaN
# J             NaN        NaN       NaN        NaN   6.488449
# Y             NaN        NaN       NaN        NaN   3.284972
# NB118         NaN        NaN       NaN        NaN   4.676753

# %%
-2.5*np.log10(flux_df)+8.9+15
# Out:
#              HST       JWST
# F606W  27.988150        NaN
# F814W  26.614628        NaN
# F125W  24.791958        NaN
# F160W  24.069933        NaN
# F115W        NaN  24.754437
# F150W        NaN  23.921863
# F277W        NaN  22.278991
# F444W        NaN  21.996135

# %% [markdown]
# # check photometry with COSMOS2020

# %%
cat = pd.read_csv('/home/lupengjun/OII_emitter/data/cosmos-info/table_irsa_catalog_search_results.csv')
cat
# Out:
#         id          ra       dec  flux_radius  flag_combined  cfht_u_mag_auto  \
# 0   809686  150.159477  2.191469      4.62408              0          24.9630
# 1   808843  150.158991  2.191279      4.10081              0          26.2482
# 2   807769  150.158351  2.191569      3.24000              0          27.6537
# 3   810799  150.160396  2.192311      5.05152              0          25.3305
# 4   807119  150.160754  2.191305      3.49794              0          29.3013
# 5   815279  150.159572  2.193206      6.70269              0          23.4971
# 6   811695  150.158181  2.190105      5.21320              0          23.9724
# 7   811353  150.161045  2.192880      4.69223              0          23.6913
# 8   809860  150.161667  2.191390      4.56188              0          24.3170
# 9   808329  150.157296  2.191524      5.04354              0          26.7991
# 10  811821  150.157510  2.192777      3.94098              0          23.5908
# 11  807483  150.156911  2.191333      4.41328              0          28.3730
# 12  807290  150.157153  2.190346      7.23135              0          26.8692
# 13  806497  150.160993  2.189329      4.43249              0          25.0948
# 14  810260  150.159207  2.194121      2.67598              0              NaN
#
#     cfht_u_magerr_auto  cfht_ustar_mag_auto  cfht_ustar_magerr_auto  \
# 0               0.0456              24.9334                  0.0244
# 1               0.0965              26.2547                  0.0536
# 2               0.3532              27.7042                  0.2070
# 3               0.0567              25.1699                  0.0274
# 4               1.0159              31.7664                  5.4593
# 5               0.0170              23.4727                  0.0092
# 6               0.0239              24.0654                  0.0142
# 7               0.0125              23.7142                  0.0071
# 8               0.0215              24.3146                  0.0122
# 9               0.2187              27.1400                  0.1631
# 10              0.0107              23.6401                  0.0062
# 11              0.8252              27.7618                  0.2549
# 12              0.2906              27.3020                  0.2321
# 13              0.0378              25.1468                  0.0225
# 14                 NaN              32.8589                 14.6012
#
#     hsc_g_mag_auto  ...  ez_restb  ez_restv  ez_restj  ez_mass_p500  \
# 0          24.4212  ...     3.413     5.843    39.917        11.019
# 1          25.6283  ...     1.977     3.731    19.880        10.711
# 2          26.8620  ...     0.066     0.100     0.267         5.997
# 3          24.9444  ...     1.262     1.543     2.755         9.869
# 4          29.8347  ...     0.022     0.031     0.063         7.653
# 5          22.9216  ...     6.881    10.198    24.362        10.458
# 6          23.4018  ...     9.535    14.396    44.927        11.047
# 7          23.4900  ...     4.057     4.530     6.567        10.144
# 8          24.1268  ...     2.208     2.686     4.282         9.868
# 9          26.1471  ...     0.453     0.510     0.841         9.554
# 10         23.3551  ...     4.988     5.944     9.900         9.914
# 11         27.5301  ...     0.054     0.068     0.246         6.590
# 12         27.5975  ...     0.186     0.220     0.514         8.903
# 13         24.8639  ...     1.128     1.390     2.151         9.347
# 14         28.0775  ...     0.118     0.131     0.120         8.928
#
#     ez_sfr_p500  ez_lv_p500   ez_lir_p500  ez_av_p500      dist       angle
# 0         1.289      10.295  3.410000e+11      2.2424  0.092310  244.362260
# 1         1.331      10.085  3.050000e+11      2.2366  1.970048  248.421433
# 2        -2.795       6.068  1.500000e+07      1.5176  4.145941  274.409845
# 3         0.468       9.931  1.560000e+10      0.3382  4.398116   47.155923
# 4        -0.911       7.955  1.320000e+09      1.2476  4.553860   97.944466
# 5         0.515      10.278  2.280000e+10      0.3724  6.219928    2.379236
# 6         1.414      10.723  2.770000e+11      1.0179  6.858158  223.788891
# 7         1.126      10.436  6.910000e+10      0.6088  7.503311   47.793531
# 8         0.506       9.964  2.250000e+10      0.4566  7.802759   92.388407
# 9         1.221       9.910  1.520000e+11      1.6912  7.929736  271.148300
# 10        1.252      10.291  1.400000e+11      0.9019  8.546833  303.107953
# 11       -2.502       6.326  3.230000e+07      1.4798  9.329007  266.747394
# 12       -0.443       8.711  3.670000e+09      0.9596  9.378592  244.190348
# 13        0.255       9.585  1.400000e+10      0.5197  9.425856  145.252588
# 14        0.486       9.759  2.650000e+10      0.4208  9.564719  353.663958
#
# [15 rows x 125 columns]

# %%
flux_col = []
for band, telescope in flux_df.stack().reset_index()[['level_0', 'level_1']].values:
    telescope_band = '_'.join([telescope, band])
    flux_col.append(telescope_band)

# %%
dic = {}

# %%
df_list = []
for col in cat.columns:
    if 'mag_auto' in col:
        telescope_band = col.split('_mag_auto')[0]
        if 'vista' in telescope_band: telescope_band = telescope_band[1:]
        telescope_band_ = telescope_band.replace('_','')
        for fcol in flux_col:
            fcol_ = fcol.replace('_','').replace('-','')
            if telescope_band_.lower() in fcol_.lower():
                print(col)
                col0, col1 = fcol.split('_')
                df_list.append([fcol, 10**((cat[col][0]-23.9)/-2.5), flux_df[col0][col1]])
                telescope, band = fcol.split('_')
                #dic[telescope] = {}
                dic[telescope][band] = cat[col][0]
# Out:
# cfht_u_mag_auto
# hsc_g_mag_auto
# hsc_r_mag_auto
# hsc_i_mag_auto
# hsc_z_mag_auto
# hsc_y_mag_auto
# uvista_y_mag_auto
# uvista_j_mag_auto
# uvista_h_mag_auto
# uvista_ks_mag_auto
# uvista_nb118_mag_auto

# %%
df_list
# Out:
# [['CFHT_u', 0.375664364614458, 0.1733423418176814],
#  ['SUBARU_HSC-G', 0.618756821701804, 0.2909926020014781],
#  ['SUBARU_HSC-R', 1.2743244035301704, 0.6529067085868473],
#  ['SUBARU_HSC-I', 3.514633142078553, 1.7182281174729268],
#  ['SUBARU_HSC-Z', 4.8319229456119075, 2.708377700471066],
#  ['SUBARU_HSC-Y', 6.787658749840561, 3.40612446879766],
#  ['VISTA_Y', 6.226442760549975, 3.284972249806678],
#  ['VISTA_J', 11.796685465590516, 6.488448713587029],
#  ['VISTA_H', 15.596961495358148, 10.2608103394546],
#  ['VISTA_Ks', 28.79254140201583, 20.352906032176705],
#  ['VISTA_NB118', 8.439563787631124, 4.676753398311365]]

# %%
dic['SPITZER'] = {}
for col in cat.columns:
    if '_magerr' in col and 'irac' in col:
        print(col)
        telescope, band = col.split('_')[:-1]
        #dic['SPITZER'][band] = 10**((cat[col][0]-23.9)/-2.5)
        dic['SPITZER'][band] = cat[col][0]
# Out:
# irac_ch1_magerr
# irac_ch2_magerr

# %%
df_array = np.array(df_list)

# %%
(df_array[:-5,1].astype(float)/df_array[:-5,2].astype(float)).mean()
# Out:
# 2.0112772554375966

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.plot(df_array[:-5,0], df_array[:-5,1].astype(float), label='COSMOS2020')
plt.plot(df_array[:-5,0], df_array[:-5,2].astype(float), label='Mine')
plt.plot(df_array[:-5,0], df_array[:-5,1].astype(float)/df_array[:-5,2].astype(float), label='COSMOS2020/Mine', linestyle='dashed')
xmin, xmax = plt.xlim()
plt.hlines(2, xmin, xmax, colors='r', linestyles='dashed')
plt.text(xmax, 2.2, 'rate=2', ha='right', va='bottom', color='r')
plt.legend()
plt.ylabel('flux/uJy')
plt.subplot(2,1,2)
plt.plot(df_array[-5:,0], df_array[-5:,1].astype(float), label='COSMOS2020')
plt.plot(df_array[-5:,0], df_array[-5:,2].astype(float), label='Mine')
plt.plot(df_array[-5:,0], df_array[-5:,1].astype(float)/df_array[-5:,2].astype(float), label='COSMOS2020/Mine', linestyle='dashed')
xmin, xmax = plt.xlim()
plt.hlines(2, xmin, xmax, colors='r', linestyles='dashed')
plt.text(xmax, 2.2, 'rate=2', ha='right', va='bottom', color='r')
plt.legend()
plt.ylabel('flux/uJy')
plt.show()

# %%
df_array[:,1].astype(float)/df_array[:,2].astype(float)
# Out:
# array([2.16718178, 2.12636616, 1.95177104, 2.04549856, 1.7840654 ,
#        1.9927806 , 1.89543238, 1.81810568, 1.52005163, 1.41466488,
#        1.80457746])

# %% [markdown]
# # calculate distances of the two galaxies

# %%
from astropy.cosmology import FlatLambdaCDM
cos = FlatLambdaCDM(70 * u.km / u.s / u.Mpc, Om0 = 0.3,)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
D_major = cos.lookback_distance(0.924)
D_minor = cos.lookback_distance(0.925)
D_btw = np.sqrt((D_major-D_minor)**2+4*D_major*D_minor*np.sin(0.0006/180*np.pi/2)**2)

# %%
D_lum = cos.luminosity_distance(0.924)
D_lum
# Out:
# <Quantity 5992.88915976 Mpc>

# %% [markdown]
# # Derive SFR from VLA 3GHz

# %%
def luminosity_1_4GHz(flux_3GHz, z, luminosity_distance, alpha=-0.7):
    '''
    flux: microJy
    luminosity_distance: Mpc
    return: W/Hz, rest-frame 1.4GHz luminosity
    '''
    return 4*np.pi*(luminosity_distance*u.Mpc.to(u.m))**2*(flux_3GHz*1e-32)*(1.4/3)**alpha/(1+z)**(1+alpha)
def q_TIR(luminosity_1_4GHz):
    '''
    the ratio of infrared-to-radio luminosity
    '''
    return -0.153*np.log10(luminosity_1_4GHz)+5.9
def L_TIR(q_TIR, luminosity_1_4GHz):
    '''
    luminosity_1_4GHz: W/Hz
    return: W
    '''
    return 10**q_TIR*luminosity_1_4GHz*3.75*10**12
def SFR_TIR(L_TIR, log_C=43.41):
    '''
    L_TIR: W
    return: Msun/yr
    '''
    log_SFR = np.log10(L_TIR*10**7)-log_C
    return 10**log_SFR

# %%
flux_3GHz = 24.6
lum_1_4GHz = luminosity_1_4GHz(flux_3GHz, 0.924, D_lum.value)
lum_1_4GHz
# Out:
# 1.4809905430647608e+23

# %%
q_TIR_ = q_TIR(lum_1_4GHz)
q_TIR_
# Out:
# 2.3549055003457213

# %%
L_TIR = L_TIR(q_TIR_, lum_1_4GHz)
L_TIR
# Out:
# 1.257445159448983e+38

# %%
SFR_TIR = SFR_TIR(L_TIR)
SFR_TIR
# Out:
# 48.9202934380188

# %%
print('L_TIR:', round(L_TIR, 2), 'W',
      '\nq_TIR:', round(q_TIR, 2),
      '\nlum_1_4GHz:', round(lum_1_4GHz, 2), 'W/Hz',
      '\nSFR_TIR:', round(SFR_TIR, 2), 'Msun/yr',)
# Out:
# L_TIR: 4.0579871449993e+38 W
# q_TIR: 2.26
# lum_1_4GHz: 5.9059013119777655e+23 W/Hz
# D_lum: 5992.89 Mpc
# SFR_TIR: 157.87 Msun/yr

# %%
D_btw.to(u.kpc)
# Out:
# <Quantity 1321.12385264 kpc>

# %%
D_ang_major = cos.angular_diameter_distance(0.924)*0.0005/180*np.pi
D_ang_major.to(u.kpc)
# Out:
# <Quantity 14.12776564 kpc>

# %%
cosmos_df = pd.DataFrame(dic)
cosmos_df.to_csv("../output/flux_sum_COSMOS2020.csv")

# %%
-2.5*np.log10(cosmos_df)+23.9
# Out:
#          CFHT   SUBARU    VISTA  SPITZER
# u      24.963      NaN      NaN      NaN
# HSC-G     NaN  24.4212      NaN      NaN
# HSC-R     NaN  23.6368      NaN      NaN
# HSC-I     NaN  22.5353      NaN      NaN
# HSC-Z     NaN  22.1897      NaN      NaN
# HSC-Y     NaN  21.8207      NaN      NaN
# Y         NaN      NaN  21.9144      NaN
# J         NaN      NaN  21.2206      NaN
# H         NaN      NaN  20.9174      NaN
# Ks        NaN      NaN  20.2518      NaN
# NB118     NaN      NaN  21.5842      NaN
# ch1       NaN      NaN      NaN  19.6752
# ch2       NaN      NaN      NaN  19.7614

# %%
cosmos_err_df = pd.DataFrame(dic)
err_down = 10**(np.log10(cosmos_df)+cosmos_err_df/-2.5)-cosmos_df

# %%
err_up = 10**(np.log10(cosmos_df)-cosmos_err_df/-2.5)-cosmos_df

# %%
err_down = abs(err_down)

# %%
err_up
# Out:
#            CFHT    SUBARU     VISTA   SPITZER
# u      0.016114       NaN       NaN       NaN
# HSC-G       NaN  0.009880       NaN       NaN
# HSC-R       NaN  0.014044       NaN       NaN
# HSC-I       NaN  0.017199       NaN       NaN
# HSC-Z       NaN  0.026776       NaN       NaN
# HSC-Y       NaN  0.043274       NaN       NaN
# Y           NaN       NaN  0.021830       NaN
# J           NaN       NaN  0.027194       NaN
# H           NaN       NaN  0.038835       NaN
# Ks          NaN       NaN  0.061058       NaN
# NB118       NaN       NaN  0.099298       NaN
# ch1         NaN       NaN       NaN  0.117406
# ch2         NaN       NaN       NaN  0.116798

# %%
err_down
# Out:
#            CFHT    SUBARU     VISTA   SPITZER
# u      0.015451       NaN       NaN       NaN
# HSC-G       NaN  0.009725       NaN       NaN
# HSC-R       NaN  0.013891       NaN       NaN
# HSC-I       NaN  0.017115       NaN       NaN
# HSC-Z       NaN  0.026629       NaN       NaN
# HSC-Y       NaN  0.043000       NaN       NaN
# Y           NaN       NaN  0.021754       NaN
# J           NaN       NaN  0.027132       NaN
# H           NaN       NaN  0.038738       NaN
# Ks          NaN       NaN  0.060929       NaN
# NB118       NaN       NaN  0.098144       NaN
# ch1         NaN       NaN       NaN  0.117125
# ch2         NaN       NaN       NaN  0.116497

# %%
err_down[err_up>err_down] = err_up[err_up>err_down]

# %%
err_down.to_csv('../output/error_sum_COSMOS2020.csv')

# %%
with fits.open('/home/lupengjun/OII_emitter/data/VLA_3GHz/CWebOII-vla_3ghz_msmf.fits') as hdu:
    print(hdu[0].header)
# Out:
# SIMPLE  =                    T /Standard FITS                                   BITPIX  =                  -32 /Floating point (32 bit)                         NAXIS   =                    2                                                  NAXIS1  =                  151                                                  NAXIS2  =                  151                                                  NAXIS3  =                    1                                                  NAXIS4  =                    1                                                  EXTEND  =                    T                                                  BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO                 BZERO   =   0.000000000000E+00                                                  BMAJ    =   2.083300000000E-04                                                  BMIN    =   2.083300000000E-04                                                  BPA     =   0.000000000000E+00                                                  BTYPE   = 'Intensity'                                                           OBJECT  = 'COSMOS3 '                                                                                                                                            BUNIT   = 'JY/BEAM '           /Brightness (pixel) unit                         EQUINOX =   2.000000000000E+03                                                  RADESYS = 'FK5     '                                                            LONPOLE =   1.800000000000E+02                                                  LATPOLE =   2.205833333330E+00                                                  PC01_01 =   1.000000000000E+00                                                  PC02_01 =   0.000000000000E+00                                                  PC03_01 =   0.000000000000E+00                                                  PC04_01 =   0.000000000000E+00                                                  PC01_02 =   0.000000000000E+00                                                  PC02_02 =   1.000000000000E+00                                                  PC03_02 =   0.000000000000E+00                                                  PC04_02 =   0.000000000000E+00                                                  PC01_03 =   0.000000000000E+00                                                  PC02_03 =   0.000000000000E+00                                                  PC03_03 =   1.000000000000E+00                                                  PC04_03 =   0.000000000000E+00                                                  PC01_04 =   0.000000000000E+00                                                  PC02_04 =   0.000000000000E+00                                                  PC03_04 =   0.000000000000E+00                                                  PC04_04 =   1.000000000000E+00                                                  CTYPE1  = 'RA---SIN'                                                            CRVAL1  =   1.501191666680E+02                                                  CDELT1  =  -5.555555617000E-05                                                  CRPIX1  =                 808.                                                  CUNIT1  = 'deg     '                                                            CTYPE2  = 'DEC--SIN'                                                            CRVAL2  =   2.205833333330E+00                                                  CDELT2  =   5.555555617000E-05                                                  CRPIX2  =                 341.                                                  CUNIT2  = 'deg     '                                                            CTYPE3  = 'FREQ    '                                                            CRVAL3  =   2.999378873790E+09                                                  CDELT3  =   2.026758016000E+09                                                   ...

# %%
VLA_wcs = WCS(fits.getheader('/home/lupengjun/OII_emitter/data/VLA_3GHz/CWebOII-vla_3ghz_msmf.fits', ext=0, memmap=False))
BMAJ, BMIN = 2.083300000000E-04*u.deg, 2.083300000000E-04*u.deg #from header
beam_area = np.pi*BMAJ*BMIN/4/np.log(2) #beam area = \pi * BMAJ * BMIN / 4 / ln(2)
pixel_area = VLA_wcs.proj_plane_pixel_area().to(u.deg**2) # from ds9 circle area
N_beams = (pixel_area.value/beam_area.value)
N_beams # total flux = sum(data)(Jy/beam) * N_beams
# Out:
# WARNING: FITSFixedWarning: PC01_01 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_01 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_01 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_01 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC01_02 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_02 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_02 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_02 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC01_03 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_03 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_03 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_03 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC01_04 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC02_04 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC03_04 = 0.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC04_04 = 1.000000000000E+00
# indices in parameterized keywords must not have leading zeroes. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: The WCS transformation has more axes (4) than the image it is associated with (2) [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56259.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -107.618000 from OBSGEO-[XYZ].
# Set OBSGEO-B to    34.078827 from OBSGEO-[XYZ].
# Set OBSGEO-H to     2115.607 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# 0.06276058042081396

# %%
# total flux = sum(data)(Jy/beam) * N_beams
0.001368442*N_beams*u.Jy.to(u.uJy)
0.0016609171*N_beams*u.Jy.to(u.uJy)
0.00048087784*N_beams*u.Jy.to(u.uJy)
0.000391769*N_beams*u.Jy.to(u.uJy)
# Out:
# 24.587649830881865

# %%
98.1*10**(-6)/N_beams
# Out:
# 0.0015630830585414094
